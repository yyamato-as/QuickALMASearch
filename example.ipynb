# %%
from main import get_line_query, get_line_observations

# %%
#radec = "4h4m42.85s 26d18m56.3s" # L1489IRS
radec = "04h19m58.45s 27d09m57.1s" # IRAS04169+2702
species = ["(13)C(18)O", "(13)C(17)O"]

line_queries = get_line_query(species, hfs=True)
line_queries
# Out:
# 26 lines found for (13)C(18)O.
# 101 lines found for (13)C(17)O.
# {'(13)C(18)O': <Table length=26>
#  Species        QNs         nu0 [GHz]  ...   g_u    E_u [K]
#    str6        str17         float64   ... float64  float64
#  ------- ----------------- ----------- ... ------- ---------
#   13C18O   J=1-0,F=1/2-1/2 104.7114035 ...     2.0   5.02533
#   13C18O   J=1-0,F=1/2-1/2 104.7114035 ...     4.0   5.02533
#   13C18O   J=2-1,F=3/2-3/2 209.4190983 ...     4.0  15.07581
#   13C18O   J=2-1,F=3/2-1/2  209.419138 ...     4.0  15.07581
#   13C18O   J=2-1,F=5/2-3/2 209.4191721 ...     6.0  15.07581
#   13C18O   J=3-2,F=5/2-5/2 314.1195653 ...     6.0  30.15113
#   13C18O   J=3-2,F=5/2-3/2 314.1196453 ...     6.0  30.15113
#   13C18O   J=3-2,F=7/2-5/2 314.1196752 ...     8.0  30.15113
#   13C18O   J=4-3,F=7/2-7/2  418.809134 ...     8.0  50.25068
#   13C18O   J=4-3,F=7/2-5/2 418.8092422 ...     8.0  50.25068
#      ...               ...         ... ...     ...       ...
# ...

# %%
line_obs = get_line_observations(radec, line_queries)
# Out:
# Searching within 5.0 arcsec region around 04h19m58.45s 27d09m57.1s...
# --------------------------------
# Number of projects = 5
# Number of observations = 5
# Number of unique subbands = 29
# Total number of subbands = 29
# 4 target(s) with ALMA data = ['04169+2702', 'IRAS04169+2702', 'MC14S', 'K04169']
# --------------------------------
# Searching for 13C18O J=1-0,F=1/2-1/2...
# Archival data found for 13C18O J=1-0,F=1/2-1/2.
#     Obs    project_code ALMA_source_name    RAJ2000    DEJ2000  \
# 25   26  2019.1.01209.S           K04169  64.993583  27.165806
#
#     ang_res_arcsec  min_freq_GHz  max_freq_GHz  central_freq_GHz  \
# 25           1.821        104.01        105.98             105.0
#
#     bandwidth_GHz  ...   frequency  velocity_resolution  obs_creator_name  \
# 25          1.969  ...  104.997957           196.324398    Maury, Anaelle
#
#     pub_title  first_author  qa2_passed  bib_reference  \
# 25                                    T
#
# ...
